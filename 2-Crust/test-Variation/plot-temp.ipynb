# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('./../../V2RhoT_gibbs/output/t0',comments='#',delimiter=',')
plt.scatter(x=data[:,1],y=data[:,2],c=data[:,4])
plt.ylim(100,0)
plt.colorbar()

# %%
data = np.loadtxt('./../../V2RhoT_gibbs/output/conversion_out.txt',comments='#',delimiter=',')
plt.scatter(x=data[:,1],y=data[:,2],c=data[:,4])
plt.ylim(100,0)
plt.colorbar()

# %%
data = np.loadtxt('./../../V2RhoT_gibbs/output/DMM_7km_HP_out.dat',comments='#',delimiter=',')
plt.scatter(x=data[:,1],y=data[:,2],c=data[:,4])
plt.ylim(100,0)
plt.colorbar()
